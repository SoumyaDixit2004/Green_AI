# %%
#single line comment
print('hello stechies')
'''
python program to explain multiple line comment
print('hello')
'''
print("hello")
# Out:
# hello stechies
# hello

# %%
# multiple assignment
x,y,z = 1,2,3
#unpacking
number = (4,5,6)
a,b,c= number

# %%
a = 5
print('type of a: ',type(a))
b = 5.0
print('\ntype of b: ',type(b))
c = 2 +4j
print("\ntype of c: ",type(c))
# Out:
# type of a:  <class 'int'>
#
# type of b:  <class 'float'>
#
# type of c:  <class 'complex'>

# %%
#booleam datatype
print(type(True))
print(type(False))
print(type(true))
# Out:
# <class 'bool'>
# <class 'bool'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 print(type(True))
#       3 print(type(False))
# ----> 4 print(type(true))
#
# NameError: name 'true' is not defined

# %%
#take user input using 'input' function
name = input("your name = ")
print("Hello , world")
# Out:
# your name =  Soumya Dixit
# Hello , world

# %%
city_name = "city A"
# print the value of the string variable
print(f'city name = {city_name}')
# Out:
# city name = city A

# %%
temperature = 25
print(f"Temperature: {temperature}℃")
# Out:
# Temperature: 25℃

# %%
carbon_footprint = 500.75 # kg CO2
#print the value of the float variable
print(f"carbon_footprint = {carbon_footprint}")
# Out:
# carbon_footprint = 500.75

# %%
is_sustainable = carbon_footprint < 400
print(f"Is the city sustainable? {is_sustainable}")
# Out:
# Is the city sustainable? False

# %%
# create a list variable for temperature 
weekly_temperature = [25,27,28,24,30,29]
print(f"Weekly Temperature: {weekly_temperature}")
# Out:
# Weekly Temperature: [25, 27, 28, 24, 30, 29]

# %%
#create a dictionary variable to store city data
city_data = {
    "name": "City A",
    "temepature": 25,
    "carbon_footprint": 500.75,
    "is_sustainable": False}
#print the dictionary
print(f"City Data: {city_data} ")
# Out:
# City Data: {'name': 'City A', 'temepature': 25, 'carbon_footprint': 500.75, 'is_sustainable': False}

# %%
#assign multiple variable at once
city_name, temperature, carbon_footprint = "city B", 30, 350.50
#print the value
print(f"City name : {city_name}, temperature: {temperature}°C , carbon footprints : {carbon_footprint} kg CO2")
# Out:
# City name : city B, temperature: 30°C , carbon footprints : 350.5 kg CO2

# %%
# if 
number = 10
if (number > 0):
    print(number)
else:
    print("number is negative")
# Out:
# 10

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#table of 3
for i in range(0,31,3):
  
    print(i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
count = 0 
while count < 5:
    print(count)
    count +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
climate_data = [
    {"city": "city A", "temperature": 25, "carbon_footprint": 500},
    {"city": "city B", "temperature": 30, "carbon_footprint": 350},
    {"city": "city C", "temperature": 22, "carbon_footprint": 600},
    {"city": "city D", "temperature": 15, "carbon_footprint": 200},
    {"city": "city E", "temperature": 28, "carbon_footprint": 450},
]
high_temp_threshold = 26
high_temp_cities = [city for city in climate_data if city["temperature"] > high_temp_threshold]
print("Cities with high temperature (> 26°C):")
for city in high_temp_cities:
    print(f"{city['city']} - {city['temperature']}°C")
# Out:
# Cities with high temperature (> 26°C):
# city B - 30°C
# city E - 28°C

# %%
total_carbon = 0
for city in climate_data:
    total_carbon += city["carbon_footprint"]
average_carbon_footprint = total_carbon / len(climate_data)
print(f"\nAverage Carbon Footprint: {average_carbon_footprint:.2f} kg CO2")
# Out:
# Average Carbon Footprint: 420.00 kg CO2

# %%
sustainability_threshold = 400
sustainable_cities = list(filter(lambda city: city["carbon_footprint"] < sustainability_threshold, climate_data))
print("\nSustainable Cities (carbon footprint < 400 kg CO2):")
for city in sustainable_cities:
    print(f"{city['city']} - {city['carbon_footprint']} kg CO2")
# Out:
# Sustainable Cities (carbon footprint < 400 kg CO2):
# city B - 350 kg CO2
# city D - 200 kg CO2

# %%
highest_footprint_city = max(climate_data, key = lambda city: city["carbon_footprint"])
print(f"\nCity with the highest carbon footprint:")
print(f"\n{highest_footprint_city['city']} - {highest_footprint_city['carbon_footprint']} kg CO2")
# Out:
# City with the highest carbon footprint:
#
# city C - 600 kg CO2
